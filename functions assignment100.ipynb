# %% [markdown]
# Python Functions, Map, Filter, Reduce, Nested Functions, Lambda and LEGB Scope
# General Instructions
# For every assignment:
#
# Write a complete Python program.
# Define meaningful functions instead of writing all logic directly.
# Use proper function names and variable names.
# Add comments explaining important logic.
# Accept input from the user wherever required.
# Display the final result clearly.
# Handle invalid inputs wherever applicable.
# Test the program with at least two different inputs.
# Do not copy the expected output directly.
# Write the complete executable code for every question.

# %%
#Assignment 1: Welcome Message Function
#Write a Python program that defines a function named welcome_student().

#Requirements
# function should accept a student's name as an argument.
#$It should return a welcome message.
#Call the function using a name entered by the user.
#Print the returned message.

# %% [markdown]
# Write a function named add_numbers() that accepts two numbers and returns their sum.
#
# Requirements
# Read two numbers from the user.
# Pass them to the function.
# Return the sum from the function.
# Print the final result.

# %%
\

# %%
rite a function named add_numbers() that accepts two numbers and returns their sum.

Requirements
Read two numbers from the user.
Pass them to the function.
Return the sum from the function.
Print the final result.
